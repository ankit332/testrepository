# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# __Ankit Srivstava__
#
# Associate Manager - IT firm

# %% [markdown]
# _I am interested in data science because I love working with data_

# %% [markdown]
# ### The code below is the code adding two numbers

# %%
sum = 2+3
print(sum)
# Out:
# 5

# %% [markdown]
# ~This line contains syntax for strikethrough~

# %% [markdown]
# * This
# * Is
# * A
# * Bulleted
# * List

# %% [markdown]
# 1. This
# 2. Is
# 3. A
# 4. Numbered
# 5. List
